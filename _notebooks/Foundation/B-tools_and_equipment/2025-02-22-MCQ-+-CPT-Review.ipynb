# %% [markdown]
# <a href = "https://prajnar123123213.github.io/teaching_frontend/teaching/"> Beneficial Harmful Effects</a>
#
# <a href = "https://martijorbam.github.io/bi5_digitaldivide/csp%20big%20idea%205/2025/03/18/digdivide_IPYNB_2_.html"> Digital Divide</a>
#
# <a href = "https://avikaprasad22.github.io/avika_2025/compbias/"> Computing Bias</a>
#
# <a href = "https://prad-coder.github.io/GenomeGamersFrontend/crowdsourcing#2-examples-of-distributed-computing"> Crowdsourcing</a>
#
# <a href = "https://noratheturtle.github.io/nora_25/2025/03/15/LegalEthical_IPYNB_2_.html"> Legal/Ethical Concerns</a>
#
# <a href = "https://prad-coder.github.io/GenomeGamersFrontend/safecomputing"> Safe Computing</a>
#
# <a href = "https://joannahu123.github.io/Jo/2025/04/04/binary.html"> Binary Search Algorithm</a>
#
# <a href = "https://githubneos.github.io/team_teach/Lists_Algorithms"> Lists and Filtering Algorithm</a>
#
# <a href = "https://illuminati1618.github.io/yash_2025/csp/random/"> Simulation/Games and Random Algorithms</a>
#
# <a href = "https://illuminati1618.github.io/yash_2025/big-o2"> Big O and Algorithm Efficiency</a>
#
# <a href = "https://alexrubio1.github.io/und_lesson/lesson/3-1"> Undecideable Problems, Graphs + Heuristics</a>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>AP CSP Review Notes</title>
# </head>
# <body>
#
# <h2>Using This Guide</h2>
# <ul>
#   <li>Red highlights = super important.</li>
#   <li>Understand your code.</li>
#   <li>Focus on Big Idea 3.</li>
#   <li>Practice lots, find weak points.</li>
# </ul>
#
# <h2>Collaboration</h2>
# <ul>
#   <li>Collaboration: Exchanging ideas, improving software.</li>
#   <li>Computing innovation: data IN, transform, OUT.</li>
#   <li>Pair programming: Two programmers, one computer.</li>
#   <li>User interface: User inputs and outputs.</li>
# </ul>
#
# <h2>Big Idea 1: Creative Development (13%)</h2>
# <ul>
#   <li>Meaningful names (e.g., stopButton).</li>
#   <li>Incremental: smaller pieces.</li>
#   <li>Iterative: prototypes, revise.</li>
#   <li>Event-driven: Responds to actions.</li>
#   <li>Input/Output: Data to/from computer.</li>
#   <li>Program: Instructions for device.</li>
#   <li>Documentation: Explains how program works.</li>
# </ul>
#
# <h2>The Development Process</h2>
# <ul>
#   <li>Sequential: In order.</li>
#   <li>Code segments: Program parts.</li>
#   <li>Syntax errors: Grammar mistakes.</li>
#   <li>Error handling: Understand program.</li>
#   <li>API: Function details, parameters, returns.</li>
#   <li>Comments: Explain code (//...).</li>
#   <li>Library: Reusable functions.</li>
#   <li>Run-time errors: Program crashes during use.</li>
#   <li>Logic errors: Unexpected behavior.</li>
#   <li>Overflow errors: Number out of range.</li>
# </ul>
#
# <h2>Big Idea 2: Data (22%)</h2>
# <ul>
#   <li>Decimal: Base 10 (0–9).</li>
#   <li>Binary: Base 2 (0 and 1).</li>
#   <li>Bit: Smallest unit (0 or 1).</li>
#   <li>Byte: 8 bits = 256 values.</li>
#   <li>Data Compression: Reduce size.</li>
#   <li>Lossless vs Lossy compression.</li>
#   <li>Analog vs Digital data (sampling).</li>
#   <li>Data cleaning, filtering, visualization.</li>
#   <li>Variables, lists, and types (int, string, bool).</li>
# </ul>
#
# <h2>Algorithms and Programming</h2>
# <ul>
#   <li>Boolean Operators: AND, OR, NOT.</li>
#   <li>IF-ELSE, nested conditionals.</li>
#   <li>Loops: While, Repeat Until (For).</li>
#   <li>Searching: Linear, Binary.</li>
#   <li>Procedures: Parameters, arguments, returns.</li>
#   <li>Algorithm: Sequence, selection, iteration.</li>
#   <li>Simulation models.</li>
#   <li>Efficiency: Polynomial vs exponential.</li>
# </ul>
#
# <h2>Computer Systems and Networks</h2>
# <ul>
#   <li>Routers, packets, bandwidth, latency.</li>
#   <li>Protocols: TCP/IP, HTTP.</li>
#   <li>WWW vs Internet.</li>
#   <li>IPv4 vs IPv6.</li>
#   <li>Fault tolerance, redundancy.</li>
#   <li>Parallel and distributed computing.</li>
# </ul>
#
# <h2>Impact of Computing</h2>
# <ul>
#   <li>Digital divide, bias in computing.</li>
#   <li>Benefits: Medical, communication, speed.</li>
#   <li>Harmful: Viruses, privacy, job loss.</li>
#   <li>Targeted advertising and PII.</li>
# </ul>
#
# <h2>Legal and Ethical Concerns</h2>
# <ul>
#   <li>Copyright, plagiarism, Creative Commons.</li>
#   <li>Fair use (PANE: Purpose, Amount, Nature, Effect).</li>
#   <li>Open source, citizen science, crowdsourcing.</li>
# </ul>
#
# <h2>Safe Computing</h2>
# <ul>
#   <li>Strong passwords, encryption, MFA.</li>
#   <li>Viruses, DDoS, phishing, keylogging.</li>
#   <li>Asymmetric/symmetric encryption, digital certificates.</li>
# </ul>
#
# <h2>General Advice for the AP Exam</h2>
# <ul>
#   <li>Read code carefully.</li>
#   <li>Skip tough questions first.</li>
#   <li>Trace variables in code.</li>
#   <li>FRQs: Be specific with code.</li>
# </ul>
#
# </body>
# </html>

# %% [markdown]
# # MCQ Review
#
# ![post]({{site.baseurl}}/images/q1.png)
#
#
# It should be log base 2 of 128 which the closest on being 7 which is B.

# %% [markdown]
# ![post]({{site.baseurl}}/images/q2.png)
#
# It should be B and C, I chose A because of a misconception of the minor and the adult.

# %% [markdown]
# ![post]({{site.baseurl}}/images/q3.png)
#
# It should be A becuase of P its 30s and Q its 10s which leads to the max of 40s.

# %% [markdown]
# ![post]({{site.baseurl}}/images/q5.png)
#
# It should be displayed as 3 becuase of the count of even and odd so the correct answer is A.

# %% [markdown]
# ![post]({{site.baseurl}}/images/q6.png)
#
# It is not A because bandwith limits the data rate and not the time. This clearly aligns with answer choice D.
