# %% [markdown]
# # Final Retrospective

# %% [markdown]
# ![post]({{site.baseurl}}/images/analytics.png)

# %% [markdown]
# ![post]({{site.baseurl}}/images/test.png)

# %% [markdown]
# ![post]({{site.baseurl}}/images/natm.png)

# %% [markdown]
# The past trimester I primarily worked on:
# - a file upload system project - learned how to set up AWS infrastructure (IAM users, policies, S3 buckets)
#
# What I want to do next in CS exploration:
# - WebSockets through a game-like platform
# - Remember exploring this last year when creating lessons - now that we know Java, feels like the right time to implement real-time, bidirectional communication

# %% [markdown]
# Something cool I wanted to share with you:
#
# - Last year I wanted to learn Verilog (hardware description language)
#
# - You advised not to jump straight in without understanding fundamentals first
#
# - I Spent the last 8 months learning digital electronics - the foundational concepts needed before Verilog
#
# - Then dedicated time to understanding Verilog syntax and design methodologies
#
# - Now at the point where I can contribute professionally
#
# - Landed an internship working on real projects that could genuinely impact employees' lives
